# %% [markdown]
# ## Monte Carlo (predicción de ganancia neta)

# %%
import numpy as np
import matplotlib.pyplot as plt

rev_m = 200
rev_stdev = 10
it = 256

rev = np.random.normal(rev_m, rev_stdev, it)
COGS = - (rev * np.random.normal(0.4,0.2))

COGS.mean(), COGS.std()
# Out:
# (-127.01614079523004, 6.517429647331937)

# %% [markdown]
# ****

# %%
Gan_Net = rev + COGS
Gan_Net
# Out:
# array([75.73591954, 69.69017527, 75.64123715, 67.6591894 , 74.54002276,
#        75.0264686 , 78.44816917, 78.58725844, 72.02395623, 79.16702633,
#        75.71627559, 71.83985867, 68.01060821, 71.24765111, 73.52255104,
#        73.03838456, 65.10769297, 69.49994891, 75.79578187, 75.13417218,
#        76.98766115, 71.49045567, 67.34382335, 77.85583976, 73.97218679,
#        79.79687995, 73.86801616, 69.21564698, 71.18214227, 69.90242885,
#        70.8678438 , 72.73062244, 71.66421973, 72.29803535, 79.03245905,
#        70.80132828, 66.95585293, 64.10953165, 75.9637716 , 73.50640184,
#        72.66741348, 69.16576759, 72.1212691 , 69.47592822, 68.6872139 ,
#        74.01655375, 76.05111422, 71.19358229, 77.20254341, 73.61969952,
#        74.78281272, 71.54002537, 74.88518923, 78.13618109, 65.32325886,
#        70.27051864, 72.92816844, 67.38239562, 73.76109524, 72.34617169,
#        78.90795026, 80.51754684, 70.51494414, 70.56520922, 70.36283949,
# ...

# %%
plt.figure(figsize=(15, 6))
plt.plot(Gan_Net)
plt.show()

# %% [markdown]
# Las ganancias mínimas y máximas que se obtuvieron fueron:

# %%
max(Gan_Net)
# Out:
# 82.92601411076498

# %%
min(Gan_Net)
# Out:
# 63.747555987057595

# %% [markdown]
# La media y desviación estándar

# %%
Gan_Net.mean()
# Out:
# 72.44619621483943

# %%
Gan_Net.std()
# Out:
# 3.7173463474080997

# %% [markdown]
# Graficamos los datos en un histograma. Usamos 20 bins para ver mejor la distribución de los datos.

# %%
plt.figure(figsize=(10, 6));
plt.hist(Gan_Net, bins = 20);
plt.show()

# %% [markdown]
# ************
